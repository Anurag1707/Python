# %%
print("")
# Out:
# heloooooo

# %%
c=int (input("Enter the degree celcious value"))
f=(9/5*c)+32
print("f is =", f)
# Out:
# f is = 37.4

# %%
r=int(input("Enter radius"))
area=3.14*r*r
c=2*3.14*r
print("area =",area)
print("circumfernce =",c)
# Out:
# area = 50.24
# circumfernce = 25.12

# %%
x=3
y=5
z=3
print(id(x),id(y),id(z))
y=8
print(id(x),id(y),id(z))
# Out:
# 140726752683192 140726752683256 140726752683192
# 140726752683192 140726752683352 140726752683192

# %%
name=input("enter you name")
print(name)
age=int (input("enter you age"))
print(age)
print("my name is ",name,"my age is",age)
# Out:
# Anurag
# 19
# my name is  Anurag  my age is 19

# %%
length=int(input("enter length"))
width=int(input("enter breath"))
x=int(length*width)
print("Area is ",x)
# Out:
# Area is  200

# %%
age=int(input("Enter your age"))
if age>18:
   print("user can vote")
else:
 print("user can't ")
# Out:
# user can vote

# %%
marks=int(input("Enter mark of student"))
if marks>=90 and marks<=100:
    print("Grade A")
elif marks>=80 and marks<=90:
    print("Grade B")    
elif marks>=70 and marks<=80:
    print("Grade C") 
elif marks>=60 and marks<=70:
    print("Grade D") 
else :
    print("Grade E")
# Out:
# Grade B

# %%
num=int(input("Enter num"))
if num%3 ==0 and num%5==0:
    print("divided")
else :
    print(" not divided")

# %%
num1=int(input("Enter num 1"))
num2=int(input("Enter num 2"))
num3=int(input("Enter num 3"))
print("3 numbers are",num1,num2,num3)
if num1>num2 and num1>num3:
    print("Largest num is", num1)
elif  num2>num1 and num2>num3: 
    print("Largest num is", num2)
else :
    print("Largest num is", num3)
# Out:
# Largest num is 80

# %%
year = int(input("Enter a year"))
if year%4==0 and year%100==0:
    print("Leap year")
else :
    print("Not Leap year")
# Out:
# Not Leap year

# %%
num1=int(input("Enter side 1"))
num2=int(input("Enter side 2"))
num3=int(input("Enter side 3"))

if num1 == num2 and num2 == num3:
    print("equilatral tr")

# %%
km=int (input("Enter "))
if km<=10:
    a=km*10
elif 100<km:
    a=10*10+(km-10)*10

# %%
print ("Anurag")
# Out:
# Anurag
